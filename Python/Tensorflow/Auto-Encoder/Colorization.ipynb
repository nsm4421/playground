# %% [markdown]
# Import modules

# %%
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import random
from tensorflow.keras import layers, Sequential

# %% [markdown]
# Load data from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataPath = os.path.join(os.getcwd(), 'drive', 'MyDrive', 'data')
print(os.listdir(dataPath))
# Out:
# ['Download.ipynb', 'train.npz']

# %%
idx = random.sample(range(2000), 500)
npz_data = np.load(os.path.join(dataPath, 'train.npz'))

train_x = npz_data['train_y'][idx]/255.
train_y = npz_data['train_x'][idx]/255.

del npz_data

# %%
train_x.shape
# Out:
# (500, 360, 640)

# %%
train_y.shape
# Out:
# (500, 360, 640, 3)

# %% [markdown]
# Visualize train set

# %%
fig, ax = plt.subplots(1, 2, figsize=(30,60))

ax[0].imshow(train_x[50], cmap = 'gray')        
ax[0].set_title('train_x (gray)', fontsize=30)

ax[1].imshow(train_y[50])                       
ax[1].set_title('train_y (colored)', fontsize=30)

plt.show()

# %% [markdown]
# numpy ---> Tensor

# %%
train_x = tf.convert_to_tensor(train_x, dtype = tf.float64)
train_y = tf.convert_to_tensor(train_y, dtype = tf.float64)
train_x = tf.expand_dims(
    train_x, axis = -1, name=None
)

# %%
train_x.shape
# Out:
# TensorShape([500, 360, 640, 1])

# %%
train_y.shape
# Out:
# TensorShape([500, 360, 640, 3])

# %% [markdown]
# Hyper parameters

# %%
N_EPOCH = 100
BATCH_SIZE = 32

# %% [markdown]
# DataLoader

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_x, train_y)).shuffle(len(train_x)).batch(BATCH_SIZE)
# test_ds = tf.data.Dataset.from_tensor_slices((test_x, test_y)).batch(BATCH_SIZE)

del train_x, train_y#, test_x, test_y

# %% [markdown]
# # Make Model

# %%
import numpy as np
from tensorflow.keras import layers, Sequential

# %% [markdown]
# Auto Encoder

# %%
model = Sequential(
    [
      # encoder
      layers.Conv2D(3, (3,3), (2,2), activation='relu', padding='same', input_shape=(360, 640, 1)),
      layers.Conv2D(32, (6,6), (5,5), activation='relu', padding='same'),
      layers.Conv2D(64, (3,3), (2,2), activation='relu', padding='same'),     
     layers.Conv2D(128, (3,3), (2,2), activation='relu', padding='same'),
   
      # decoder
     layers.Conv2DTranspose(256, (3,3), (2,2), activation ='relu', padding='same'),
      layers.Conv2DTranspose(128, (3,3), (2,2), activation ='relu', padding='same'),
      layers.Conv2DTranspose(32, (6,6), (5,5), activation ='relu', padding='same'),
      layers.Conv2DTranspose(3, (3,3), (2,2), activation ='relu', padding='same'),

    ]
)

# %%
model.compile(optimizer = 'adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 180, 320, 3)       30
#
#  conv2d_12 (Conv2D)          (None, 36, 64, 32)        3488
#
#  conv2d_13 (Conv2D)          (None, 18, 32, 64)        18496
#
#  conv2d_14 (Conv2D)          (None, 9, 16, 128)        73856
#
#  conv2d_transpose_10 (Conv2D  (None, 18, 32, 256)      295168
#  Transpose)
#
#  conv2d_transpose_11 (Conv2D  (None, 36, 64, 128)      295040
#  Transpose)
#
#  conv2d_transpose_12 (Conv2D  (None, 180, 320, 32)     147488
#  Transpose)
#
#  conv2d_transpose_13 (Conv2D  (None, 360, 640, 3)      867
#  Transpose)
#
# =================================================================
# Total params: 834,433
# Trainable params: 834,433
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
history = model.fit(train_ds,
      batch_size = BATCH_SIZE,
      epochs = N_EPOCH,
      verbose = 1)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 10s 420ms/step - loss: 0.1176
# Epoch 2/100
# 16/16 [==============================] - 5s 338ms/step - loss: 0.0565
# Epoch 3/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0310
# Epoch 4/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0229
# Epoch 5/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0203
# Epoch 6/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0191
# Epoch 7/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0196
# Epoch 8/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0179
# Epoch 9/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0173
# Epoch 10/100
# 16/16 [==============================] - 5s 312ms/step - loss: 0.0172
# Epoch 11/100
# 16/16 [==============================] - 5s 312ms/step - loss: 0.0172
# Epoch 12/100
# 16/16 [==============================] - 5s 325ms/step - loss: 0.0162
# Epoch 13/100
# 16/16 [==============================] - 5s 310ms/step - loss: 0.0163
# Epoch 14/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0157
# Epoch 15/100
# 16/16 [==============================] - 6s 354ms/step - loss: 0.0152
# Epoch 16/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0151
# Epoch 17/100
# 16/16 [==============================] - 5s 312ms/step - loss: 0.0147
# Epoch 18/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0147
# Epoch 19/100
# 16/16 [==============================] - 5s 312ms/step - loss: 0.0144
# Epoch 20/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0143
# Epoch 21/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0141
# Epoch 22/100
# 16/16 [==============================] - 6s 346ms/step - loss: 0.0144
# Epoch 23/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0145
# Epoch 24/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0141
# Epoch 25/100
# 16/16 [==============================] - 5s 311ms/step - loss: 0.0135
# Epoch 26/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0135
# Epoch 27/100
# 16/16 [==============================] - 5s 326ms/step - loss: 0.0134
# Epoch 28/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0132
# Epoch 29/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0130
# Epoch 30/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0130
# Epoch 31/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0133
# Epoch 32/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0130
# Epoch 33/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0128
# Epoch 34/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0129
# Epoch 35/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0127
# Epoch 36/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0128
# Epoch 37/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0126
# Epoch 38/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0126
# Epoch 39/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0126
# Epoch 40/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0125
# Epoch 41/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0127
# Epoch 42/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0125
# Epoch 43/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0122
# Epoch 44/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0139
# Epoch 45/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0127
# Epoch 46/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0122
# Epoch 47/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0120
# Epoch 48/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0118
# Epoch 49/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0119
# Epoch 50/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0117
# Epoch 51/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0118
# Epoch 52/100
# 16/16 [==============================] - 5s 312ms/step - loss: 0.0118
# Epoch 53/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0116
# Epoch 54/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0117
# Epoch 55/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0117
# Epoch 56/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0115
# Epoch 57/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0116
# Epoch 58/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0119
# Epoch 59/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0129
# Epoch 60/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0121
# Epoch 61/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0118
# Epoch 62/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0114
# Epoch 63/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0119
# Epoch 64/100
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0115
# Epoch 65/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0112
# Epoch 66/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0113
# Epoch 67/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0113
# Epoch 68/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0112
# Epoch 69/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0112
# Epoch 70/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0111
# Epoch 71/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0111
# Epoch 72/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0112
# Epoch 73/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0109
# Epoch 74/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0108
# Epoch 75/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0110
# Epoch 76/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0108
# Epoch 77/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0108
# Epoch 78/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0110
# Epoch 79/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0108
# Epoch 80/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0108
# Epoch 81/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0108
# Epoch 82/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0109
# Epoch 83/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0107
# Epoch 84/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0110
# Epoch 85/100
# 16/16 [==============================] - 5s 318ms/step - loss: 0.0111
# Epoch 86/100
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0112
# Epoch 87/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.0106
# Epoch 88/100
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0107
# Epoch 89/100
# 16/16 [==============================] - 5s 313ms/step - loss: 0.0106
# Epoch 90/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0102
# Epoch 91/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0100
# Epoch 92/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0107
# Epoch 93/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0103
# Epoch 94/100
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0099
# Epoch 95/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0105
# Epoch 96/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0101
# Epoch 97/100
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0098
# Epoch 98/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0098
# Epoch 99/100
# 16/16 [==============================] - 5s 317ms/step - loss: 0.0099
# Epoch 100/100
# 16/16 [==============================] - 5s 315ms/step - loss: 0.0099

# %% [markdown]
# # History

# %%
plt.plot(history.history['loss'])
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# # Inference

# %%
sample_batch = next(iter(train_ds))

sample_train_x = sample_batch[0]
sample_train_y = sample_batch[1]
sample_predicted = model(sample_train_x)

sample_train_x = sample_train_x[0].numpy()
sample_train_y = sample_train_y[0].numpy()
sample_predicted = sample_predicted[0].numpy()

# %%
fig, ax = plt.subplots(3, figsize = (16, 8))


ax[0].imshow(sample_train_x[:, :, 0], cmap = 'gray')
ax[1].imshow(sample_predicted)
ax[2].imshow(sample_train_y)

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
